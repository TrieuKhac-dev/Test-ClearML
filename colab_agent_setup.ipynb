# %%
# ClearML Colab Agent Setup with pixi environment
# 1. Install pixi and setup environments
# %pip install -U pixi
# !pixi install
# !pixi run python --version  # Check pixi Python version
# %pip install clearml-agent scikit-learn numpy joblib  # Install all required packages for agent
# !clearml-agent --version  # Check agent version before running
# Out:
# Requirement already satisfied: pixi in /usr/local/lib/python3.12/dist-packages (1.0.1)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /usr/local/lib/python3.12/dist-packages (from pixi) (1.4.4)
# Requirement already satisfied: click<8.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from pixi) (7.1.2)
# Requirement already satisfied: pixiv-api<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from pixi) (0.3.7)
# Requirement already satisfied: tqdm<5.0,>=4.32 in /usr/local/lib/python3.12/dist-packages (from pixi) (4.67.2)
# Requirement already satisfied: cloudscraper<2.0.0,>=1.2.48 in /usr/local/lib/python3.12/dist-packages (from pixiv-api<0.4.0,>=0.3.0->pixi) (1.2.71)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pixiv-api<0.4.0,>=0.3.0->pixi) (2.32.4)
# Requirement already satisfied: pyparsing>=2.4.7 in /usr/local/lib/python3.12/dist-packages (from cloudscraper<2.0.0,>=1.2.48->pixiv-api<0.4.0,>=0.3.0->pixi) (3.3.2)
# Requirement already satisfied: requests-toolbelt>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from cloudscraper<2.0.0,>=1.2.48->pixiv-api<0.4.0,>=0.3.0->pixi) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->pixiv-api<0.4.0,>=0.3.0->pixi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->pixiv-api<0.4.0,>=0.3.0->pixi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->pixiv-api<0.4.0,>=0.3.0->pixi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->pixiv-api<0.4.0,>=0.3.0->pixi) (2026.1.4)
# The database needs to be migrated.
# Run `pixi migrate`.
# The database needs to be migrated.
# Run `pixi migrate`.
# Requirement already satisfied: clearml-agent in /usr/local/lib/python3.12/dist-packages (2.0.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)
# Requirement already satisfied: psutil<7.1,>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from clearml-agent) (5.9.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from clearml-agent) (2.5.0)
# Requirement already satisfied: virtualenv<21,>=16 in /usr/local/lib/python3.12/dist-packages (from clearml-agent) (20.36.1)
# Requirement already satisfied: requests<2.33,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from clearml-agent) (2.32.4)
# Requirement already satisfied: setuptools<82.0.0 in /usr/local/lib/python3.12/dist-packages (from clearml-agent) (75.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<2.33,>=2.20.0->clearml-agent) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<2.33,>=2.20.0->clearml-agent) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<2.33,>=2.20.0->clearml-agent) (2026.1.4)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv<21,>=16->clearml-agent) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.20.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv<21,>=16->clearml-agent) (3.20.3)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv<21,>=16->clearml-agent) (4.5.1)
# CLEARML-AGENT version 2.0.7

# %%
# 2. Thiết lập credentials (copy từ .env)
import os
os.environ['CLEARML_API_ACCESS_KEY'] = '4NRODIJF81SY18WNVISCPCV4426US0'
os.environ['CLEARML_API_SECRET_KEY'] = 'bpZvr0qPo6x59jveFnSr0tVudWgtoUoc4aCAe8bCw1aaF2YdeTVBXlSa3mMJeqgMxqc'
os.environ['CLEARML_API_HOST'] = 'https://api.clear.ml'  # Sử dụng CLEARML_API_HOST thay cho CLEARML_SERVER_HOST

# %%
# 4. Run agent in Colab to receive tasks
print('🚦 Starting clearml-agent in Colab, Colab will act as agent for local tasks...')
# !clearml-agent --version  # Check agent version before running
# !clearml-agent daemon --queue default --foreground
# Out:
# 🚦 Starting clearml-agent in Colab, Colab will act as agent for local tasks...
# CLEARML-AGENT version 2.0.7
# Using environment access key CLEARML_API_ACCESS_KEY=4NRODIJF81SY18WNVISCPCV4426US0
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Current configuration (clearml_agent v2.0.7, location: None):
# ----------------------
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.credentials.access_key = 4NRODIJF81SY18WNVISCPCV4426US0
# api.credentials.secret_key = ****
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# agent.worker_id =
# agent.worker_name = 0e45a6e61974
# agent.force_git_ssh_protocol = false
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /root/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /root/.clearml/vcs-cache
# agent.venv_update.enabled = false
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /root/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /root/.clearml/pip-cache
# agent.docker_apt_cache = /root/.clearml/apt-cache
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.12
# agent.cuda_version = 125
# agent.cudnn_version = 0
#
# Worker "0e45a6e61974:gpuall" - Listening to queues:
# +----------------------------------+---------+-------+
# | id                               | name    | tags  |
# +----------------------------------+---------+-------+
# | 07cc126032d64073bc717c01760a7c7d | default |       |
# +----------------------------------+---------+-------+
#
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# task eec9a44557d442729cd765f341628abe pulled from 07cc126032d64073bc717c01760a7c7d by worker 0e45a6e61974:gpuall
# Using environment access key CLEARML_API_ACCESS_KEY=4NRODIJF81SY18WNVISCPCV4426US0
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Running task 'eec9a44557d442729cd765f341628abe'
# Storing stdout and stderr log to '/tmp/.clearml_agent_out.5rzl8qt7.txt', '/tmp/.clearml_agent_out.5rzl8qt7.txt'
# Using custom configuration file from env var: /tmp/.clearml_agent.w23ozsd6.cfg
# Using environment access key CLEARML_API_ACCESS_KEY=4NRODIJF81SY18WNVISCPCV4426US0
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Current configuration (clearml_agent v2.0.7, location: /tmp/.clearml_agent.w23ozsd6.cfg):
# ----------------------
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.credentials.access_key = 4NRODIJF81SY18WNVISCPCV4426US0
# api.credentials.secret_key = ****
# api.host = https://api.clear.ml
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# agent.worker_id = 0e45a6e61974:gpuall
# agent.worker_name = 0e45a6e61974
# agent.force_git_ssh_protocol = false
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /root/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /root/.clearml/vcs-cache
# agent.venv_update.enabled = false
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /root/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /root/.clearml/pip-cache
# agent.docker_apt_cache = /root/.clearml/apt-cache
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.12
# agent.cuda_version = 125
# agent.cudnn_version = 0
#
# Executing task id [eec9a44557d442729cd765f341628abe]:
# repository = https://github.com/TrieuKhac-dev/Test-ClearML.git
# branch = main
# version_num = 265119a47905a7e47b2f0e5208afa744fc55c0d2
# tag =
# docker_cmd =
# entry_point = train_finetune.py
# working_dir = .
#
# Python executable with version '3.11' requested by the Task, not found in path, using '/usr/bin/python3' (v3.12.12) instead
# created virtual environment CPython3.12.12.final.0-64 in 137ms
#   creator CPython3Posix(dest=/root/.clearml/venvs-builds/3.12, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.3
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
#
#
# INFO: acquiring [timeout=300s] lock for repo cache folder
# Using cached repository in "/root/.clearml/vcs-cache/Test-ClearML.git.e8c9f8cecf0a64bcd4697512dc7d7562/Test-ClearML.git"
# pulling git
# pulling git completed
# Note: switching to '265119a47905a7e47b2f0e5208afa744fc55c0d2'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 265119a new
# type: git
# url: https://github.com/TrieuKhac-dev/Test-ClearML.git
# branch: HEAD
# commit: 265119a47905a7e47b2f0e5208afa744fc55c0d2
# root: /root/.clearml/venvs-builds/3.12/task_repository/Test-ClearML.git
# Applying uncommitted changes
#
#
# Ignoring pip: markers 'python_version < "3.10"' don't match your environment
# Ignoring pip: markers 'python_version >= "3.10" and python_version <= "3.11"' don't match your environment
# Collecting pip<24.3,>=23
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-24.2
# INFO: Using legacy resolver for PIP to avoid inconsistency with package versions!
# Collecting Cython
#   Using cached cython-3.2.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
# Installing collected packages: Cython
# Successfully installed Cython-3.2.4
# Trying pip install: /root/.clearml/venvs-builds/3.12/task_repository/Test-ClearML.git/requirements.txt
# Collecting clearml (from -r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached clearml-2.1.3-py2.py3-none-any.whl (1.4 MB)
# Collecting attrs>=18.0 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Collecting furl>=2.0.0 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Collecting jsonschema>=2.6.0 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached jsonschema-4.26.0-py3-none-any.whl (90 kB)
# Collecting numpy>=1.10 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Collecting pathlib2>=2.3.0 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Collecting psutil>=3.4.2 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Collecting pyparsing>=2.0.3 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Collecting python-dateutil>=2.6.1 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting pyjwt<2.11.0,>=2.4.0 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting PyYAML>=3.12 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
# Collecting six>=1.16.0 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting urllib3>=1.21.1 (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting Pillow>=10.3.0; python_version >= "3.8" (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Collecting referencing<0.40; python_version >= "3.8" (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting requests>=2.32.0; python_version >= "3.8" (from clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6.0->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.25.0 (from jsonschema>=2.6.0->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached rpds_py-0.30.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (394 kB)
# Collecting typing-extensions>=4.4.0; python_version < "3.13" (from referencing<0.40; python_version >= "3.8"->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.0; python_version >= "3.8"->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting idna<4,>=2.5 (from requests>=2.32.0; python_version >= "3.8"->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.0; python_version >= "3.8"->clearml->-r /tmp/requirements_zyuqbb9q.txt (line 2))
#   Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Installing collected packages: attrs, six, orderedmultidict, furl, rpds-py, typing-extensions, referencing, jsonschema-specifications, jsonschema, numpy, pathlib2, psutil, pyparsing, python-dateutil, pyjwt, PyYAML, urllib3, Pillow, charset_normalizer, idna, certifi, requests, clearml
# Successfully installed Pillow-12.1.0 PyYAML-6.0.3 attrs-25.4.0 certifi-2026.1.4 charset_normalizer-3.4.4 clearml-2.1.3 furl-2.1.4 idna-3.11 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 numpy-2.4.2 orderedmultidict-1.0.2 pathlib2-2.3.7.post1 psutil-7.2.2 pyjwt-2.10.1 pyparsing-3.3.2 python-dateutil-2.9.0.post0 referencing-0.37.0 requests-2.32.5 rpds-py-0.30.0 six-1.17.0 typing-extensions-4.15.0 urllib3-2.6.3
# Adding venv into cache: /root/.clearml/venvs-builds/3.12
# Running task id [eec9a44557d442729cd765f341628abe]:
# [.]$ /root/.clearml/venvs-builds/3.12/bin/python -u train_finetune.py
# Summary - installed python packages:
# pip:
# - attrs==25.4.0
# - certifi==2026.1.4
# - charset-normalizer==3.4.4
# - clearml==2.1.3
# - Cython==3.2.4
# - furl==2.1.4
# - idna==3.11
# - jsonschema-specifications==2025.9.1
# - jsonschema==4.26.0
# - numpy==2.4.2
# - orderedmultidict==1.0.2
# - pathlib2==2.3.7.post1
# - pillow==12.1.0
# - psutil==7.2.2
# - PyJWT==2.10.1
# - pyparsing==3.3.2
# - python-dateutil==2.9.0.post0
# - PyYAML==6.0.3
# - referencing==0.37.0
# - requests==2.32.5
# - rpds-py==0.30.0
# - six==1.17.0
# - typing_extensions==4.15.0
# - urllib3==2.6.3
#
# Environment setup completed successfully
#
# Starting Task Execution:
#
# ClearML results page: https://app.clear.ml/projects/b27b7f2e3c75434299d1c426cfda940f/experiments/eec9a44557d442729cd765f341628abe/output/log
# Traceback (most recent call last):
#   File "/root/.clearml/venvs-builds/3.12/task_repository/Test-ClearML.git/train_finetune.py", line 10, in <module>
#     from sklearn.datasets import load_digits
# ModuleNotFoundError: No module named 'sklearn'
#
# Leaving process id 4642
# DONE: Running task 'eec9a44557d442729cd765f341628abe', exit status 1
# Process failed, exit code 1No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# task 6ad1a4b4fb6041a698d65f9ddcb63345 pulled from 07cc126032d64073bc717c01760a7c7d by worker 0e45a6e61974:gpuall
# Running task '6ad1a4b4fb6041a698d65f9ddcb63345'
# Storing stdout and stderr log to '/tmp/.clearml_agent_out.52ylx7my.txt', '/tmp/.clearml_agent_out.52ylx7my.txt'
# Using custom configuration file from env var: /tmp/.clearml_agent.w23ozsd6.cfg
# Using environment access key CLEARML_API_ACCESS_KEY=4NRODIJF81SY18WNVISCPCV4426US0
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Current configuration (clearml_agent v2.0.7, location: /tmp/.clearml_agent.w23ozsd6.cfg):
# ----------------------
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.credentials.access_key = 4NRODIJF81SY18WNVISCPCV4426US0
# api.credentials.secret_key = ****
# api.host = https://api.clear.ml
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# agent.worker_id = 0e45a6e61974:gpuall
# agent.worker_name = 0e45a6e61974
# agent.force_git_ssh_protocol = false
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /root/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /root/.clearml/vcs-cache
# agent.venv_update.enabled = false
# agent.pip_download_cache.enabled = true
# agent.pip_download_cache.path = /root/.clearml/pip-download-cache
# agent.translate_ssh = true
# agent.translate_ssl_replacement_scheme = https
# agent.reload_config = false
# agent.docker_pip_cache = /root/.clearml/pip-cache
# agent.docker_apt_cache = /root/.clearml/apt-cache
# agent.docker_force_pull = false
# agent.default_docker.image = nvidia/cuda:12.6.3-cudnn-runtime-ubuntu20.04
# agent.default_docker.update_back_task = true
# agent.default_docker.match_rules.0.image = python:3.6-bullseye
# agent.default_docker.match_rules.0.arguments = --ipc\=host
# agent.default_docker.match_rules.0.update_back_task = true
# agent.default_docker.match_rules.0.match.script.binary = python3.6$
# agent.default_docker.match_rules.1.image = python:3.7-bullseye
# agent.default_docker.match_rules.1.arguments = --ipc\=host
# agent.default_docker.match_rules.1.update_back_task = true
# agent.default_docker.match_rules.1.match.script.binary = python3.7$
# agent.default_docker.match_rules.2.image = python:3.8-bullseye
# agent.default_docker.match_rules.2.arguments = --ipc\=host
# agent.default_docker.match_rules.2.match.script.binary = python3.8$
# agent.default_docker.match_rules.3.image = python:3.9-bullseye
# agent.default_docker.match_rules.3.arguments = --ipc\=host
# agent.default_docker.match_rules.3.match.script.binary = python3.9$
# agent.default_docker.match_rules.4.image = python:3.10-bullseye
# agent.default_docker.match_rules.4.arguments = --ipc\=host
# agent.default_docker.match_rules.4.match.script.binary = python3.10$
# agent.default_docker.match_rules.5.image = python:3.11-bullseye
# agent.default_docker.match_rules.5.arguments = --ipc\=host
# agent.default_docker.match_rules.5.match.script.binary = python3.11$
# agent.default_docker.match_rules.6.image = python:3.12-bullseye
# agent.default_docker.match_rules.6.arguments = --ipc\=host
# agent.default_docker.match_rules.6.match.script.binary = python3.12$
# agent.default_docker.match_rules.7.image = python:3.13-bullseye
# agent.default_docker.match_rules.7.arguments = --ipc\=host
# agent.default_docker.match_rules.7.match.script.binary = python3.13$
# agent.enable_task_env = false
# agent.sanitize_config_printout = ****
# agent.hide_docker_command_env_vars.enabled = true
# agent.hide_docker_command_env_vars.parse_embedded_urls = true
# agent.abort_callback_max_timeout = 1800
# agent.docker_internal_mounts.sdk_cache = /clearml_agent_cache
# agent.docker_internal_mounts.apt_cache = /var/cache/apt/archives
# agent.docker_internal_mounts.ssh_folder = ~/.ssh
# agent.docker_internal_mounts.ssh_ro_folder = /.ssh
# agent.docker_internal_mounts.pip_cache = /root/.cache/pip
# agent.docker_internal_mounts.poetry_cache = /root/.cache/pypoetry
# agent.docker_internal_mounts.vcs_cache = /root/.clearml/vcs-cache
# agent.docker_internal_mounts.venvs_cache = /root/.clearml/venvs-cache
# agent.docker_internal_mounts.venv_build = ~/.clearml/venvs-builds
# agent.docker_internal_mounts.pip_download = /root/.clearml/pip-download-cache
# agent.apply_environment = true
# agent.apply_files = true
# agent.custom_build_script =
# agent.disable_task_docker_override = false
# agent.default_python = 3.12
# agent.cuda_version = 125
# agent.cudnn_version = 0
#
# Executing task id [6ad1a4b4fb6041a698d65f9ddcb63345]:
# repository = https://github.com/TrieuKhac-dev/Test-ClearML.git
# branch = main
# version_num = 410d73b88b7f86349d9f29290068d778fb45cb22
# tag =
# docker_cmd =
# entry_point = train_finetune.py
# working_dir = .
#
# Python executable with version '3.11' requested by the Task, not found in path, using '/usr/bin/python3' (v3.12.12) instead
# created virtual environment CPython3.12.12.final.0-64 in 142ms
#   creator CPython3Posix(dest=/root/.clearml/venvs-builds/3.12, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==25.3
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
#
#
# INFO: acquiring [timeout=300s] lock for repo cache folder
# Using cached repository in "/root/.clearml/vcs-cache/Test-ClearML.git.e8c9f8cecf0a64bcd4697512dc7d7562/Test-ClearML.git"
# pulling git
# From https://github.com/TrieuKhac-dev/Test-ClearML
#    265119a..410d73b  main       -> origin/main
# pulling git completed
# Note: switching to '410d73b88b7f86349d9f29290068d778fb45cb22'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 410d73b requirement
# type: git
# url: https://github.com/TrieuKhac-dev/Test-ClearML.git
# branch: HEAD
# commit: 410d73b88b7f86349d9f29290068d778fb45cb22
# root: /root/.clearml/venvs-builds/3.12/task_repository/Test-ClearML.git
# Applying uncommitted changes
#
#
# Ignoring pip: markers 'python_version < "3.10"' don't match your environment
# Ignoring pip: markers 'python_version >= "3.10" and python_version <= "3.11"' don't match your environment
# Collecting pip<24.3,>=23
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-24.2
# INFO: Using legacy resolver for PIP to avoid inconsistency with package versions!
# Collecting Cython
#   Using cached cython-3.2.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
# Installing collected packages: Cython
# Successfully installed Cython-3.2.4
# Trying pip install: /root/.clearml/venvs-builds/3.12/task_repository/Test-ClearML.git/requirements.txt
# Collecting numpy
#   Using cached numpy-2.4.2-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.4.2
# Collecting scikit-learn (from -r /tmp/requirements_4hwm99n2.txt (line 3))
#   Downloading scikit_learn-1.8.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 107.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /root/.clearml/venvs-builds/3.12/lib/python3.12/site-packages (from -r /tmp/requirements_4hwm99n2.txt (line 4)) (2.4.2)
# Collecting joblib (from -r /tmp/requirements_4hwm99n2.txt (line 5))
#   Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Collecting clearml (from -r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached clearml-2.1.3-py2.py3-none-any.whl (1.4 MB)
# Collecting scipy>=1.10.0 (from scikit-learn->-r /tmp/requirements_4hwm99n2.txt (line 3))
#   Downloading scipy-1.17.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 63.2 MB/s eta 0:00:00
# Collecting threadpoolctl>=3.2.0 (from scikit-learn->-r /tmp/requirements_4hwm99n2.txt (line 3))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting attrs>=18.0 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Collecting furl>=2.0.0 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Collecting jsonschema>=2.6.0 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached jsonschema-4.26.0-py3-none-any.whl (90 kB)
# Collecting pathlib2>=2.3.0 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Collecting psutil>=3.4.2 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
# Collecting pyparsing>=2.0.3 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Collecting python-dateutil>=2.6.1 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Collecting pyjwt<2.11.0,>=2.4.0 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Collecting PyYAML>=3.12 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
# Collecting six>=1.16.0 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Collecting urllib3>=1.21.1 (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Collecting Pillow>=10.3.0; python_version >= "3.8" (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Collecting referencing<0.40; python_version >= "3.8" (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting requests>=2.32.0; python_version >= "3.8" (from clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6.0->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting rpds-py>=0.25.0 (from jsonschema>=2.6.0->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached rpds_py-0.30.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (394 kB)
# Collecting typing-extensions>=4.4.0; python_version < "3.13" (from referencing<0.40; python_version >= "3.8"->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.32.0; python_version >= "3.8"->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached charset_normalizer-3.4.4-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Collecting idna<4,>=2.5 (from requests>=2.32.0; python_version >= "3.8"->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached idna-3.11-py3-none-any.whl (71 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.0; python_version >= "3.8"->clearml->-r /tmp/requirements_4hwm99n2.txt (line 6))
#   Using cached certifi-2026.1.4-py3-none-any.whl (152 kB)
# Installing collected packages: scipy, joblib, threadpoolctl, scikit-learn, attrs, six, orderedmultidict, furl, rpds-py, typing-extensions, referencing, jsonschema-specifications, jsonschema, pathlib2, psutil, pyparsing, python-dateutil, pyjwt, PyYAML, urllib3, Pillow, charset_normalizer, idna, certifi, requests, clearml
# Successfully installed Pillow-12.1.0 PyYAML-6.0.3 attrs-25.4.0 certifi-2026.1.4 charset_normalizer-3.4.4 clearml-2.1.3 furl-2.1.4 idna-3.11 joblib-1.5.3 jsonschema-4.26.0 jsonschema-specifications-2025.9.1 orderedmultidict-1.0.2 pathlib2-2.3.7.post1 psutil-7.2.2 pyjwt-2.10.1 pyparsing-3.3.2 python-dateutil-2.9.0.post0 referencing-0.37.0 requests-2.32.5 rpds-py-0.30.0 scikit-learn-1.8.0 scipy-1.17.0 six-1.17.0 threadpoolctl-3.6.0 typing-extensions-4.15.0 urllib3-2.6.3
# Adding venv into cache: /root/.clearml/venvs-builds/3.12
# Running task id [6ad1a4b4fb6041a698d65f9ddcb63345]:
# [.]$ /root/.clearml/venvs-builds/3.12/bin/python -u train_finetune.py
# Summary - installed python packages:
# pip:
# - attrs==25.4.0
# - certifi==2026.1.4
# - charset-normalizer==3.4.4
# - clearml==2.1.3
# - Cython==3.2.4
# - furl==2.1.4
# - idna==3.11
# - joblib==1.5.3
# - jsonschema-specifications==2025.9.1
# - jsonschema==4.26.0
# - numpy==2.4.2
# - orderedmultidict==1.0.2
# - pathlib2==2.3.7.post1
# - pillow==12.1.0
# - psutil==7.2.2
# - PyJWT==2.10.1
# - pyparsing==3.3.2
# - python-dateutil==2.9.0.post0
# - PyYAML==6.0.3
# - referencing==0.37.0
# - requests==2.32.5
# - rpds-py==0.30.0
# - scikit-learn==1.8.0
# - scipy==1.17.0
# - six==1.17.0
# - threadpoolctl==3.6.0
# - typing_extensions==4.15.0
# - urllib3==2.6.3
#
# Environment setup completed successfully
#
# Starting Task Execution:
#
# ClearML results page: https://app.clear.ml/projects/b27b7f2e3c75434299d1c426cfda940f/experiments/6ad1a4b4fb6041a698d65f9ddcb63345/output/log
# Traceback (most recent call last):
#   File "/root/.clearml/venvs-builds/3.12/task_repository/Test-ClearML.git/train_finetune.py", line 31, in <module>
#     model = LogisticRegression(max_iter=1000, solver='lbfgs', multi_class='auto')
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: LogisticRegression.__init__() got an unexpected keyword argument 'multi_class'
#
# Leaving process id 5327
# DONE: Running task '6ad1a4b4fb6041a698d65f9ddcb63345', exit status 1
# Process failed, exit code 1No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# task e42077bb1dcc4616aae70f03cc2d545e pulled from 07cc126032d64073bc717c01760a7c7d by worker 0e45a6e61974:gpuall
# Running task 'e42077bb1dcc4616aae70f03cc2d545e'
# Storing stdout and stderr log to '/tmp/.clearml_agent_out.j45u2cuh.txt', '/tmp/.clearml_agent_out.j45u2cuh.txt'
# Using custom configuration file from env var: /tmp/.clearml_agent.w23ozsd6.cfg
# Using environment access key CLEARML_API_ACCESS_KEY=4NRODIJF81SY18WNVISCPCV4426US0
# Using environment secret key CLEARML_API_SECRET_KEY=********
# Current configuration (clearml_agent v2.0.7, location: /tmp/.clearml_agent.w23ozsd6.cfg):
# ----------------------
# api.version = 1.5
# api.verify_certificate = true
# api.default_version = 1.5
# api.http.max_req_size = 15728640
# api.http.retries.total = 240
# api.http.retries.connect = 240
# api.http.retries.read = 240
# api.http.retries.redirect = 240
# api.http.retries.status = 240
# api.http.retries.backoff_factor = 1.0
# api.http.retries.backoff_max = 120.0
# api.http.wait_on_maintenance_forever = true
# api.http.pool_maxsize = 512
# api.http.pool_connections = 512
# api.auth.token_expiration_threshold_sec = ****
# api.api_server = https://api.clear.ml
# api.credentials.access_key = 4NRODIJF81SY18WNVISCPCV4426US0
# api.credentials.secret_key = ****
# api.host = https://api.clear.ml
# sdk.storage.cache.default_base_dir = ~/.clearml/cache
# sdk.storage.cache.size.min_free_bytes = 10GB
# sdk.storage.direct_access.0.url = file://*
# sdk.metrics.file_history_size = 100
# sdk.metrics.matplotlib_untitled_history_size = 100
# sdk.metrics.images.format = JPEG
# sdk.metrics.images.quality = 87
# sdk.metrics.images.subsampling = 0
# sdk.metrics.tensorboard_single_series_per_graph = false
# sdk.network.metrics.file_upload_threads = 4
# sdk.network.metrics.file_upload_starvation_warning_sec = 120
# sdk.network.iteration.max_retries_on_server_error = 5
# sdk.network.iteration.retry_backoff_factor_sec = 10
# sdk.aws.s3.key =
# sdk.aws.s3.secret = ****
# sdk.aws.s3.region =
# sdk.aws.boto3.pool_connections = 512
# sdk.aws.boto3.max_multipart_concurrency = 16
# sdk.log.null_log_propagate = false
# sdk.log.task_log_buffer_capacity = 66
# sdk.log.disable_urllib3_info = true
# sdk.development.task_reuse_time_window_in_hours = 72.0
# sdk.development.vcs_repo_detect_async = true
# sdk.development.store_uncommitted_code_diff = true
# sdk.development.support_stopping = true
# sdk.development.default_output_uri =
# sdk.development.force_analyze_entire_repo = false
# sdk.development.suppress_update_message = false
# sdk.development.detect_with_pip_freeze = false
# sdk.development.worker.report_period_sec = 2
# sdk.development.worker.ping_period_sec = 30
# sdk.development.worker.log_stdout = true
# sdk.development.worker.report_global_mem_used = false
# agent.worker_id = 0e45a6e61974:gpuall
# agent.worker_name = 0e45a6e61974
# agent.force_git_ssh_protocol = false
# agent.python_binary =
# agent.package_manager.type = pip
# agent.package_manager.pip_version.0 = <20.2 ; python_version < '3.10'
# agent.package_manager.pip_version.1 = <22.3 ; python_version >\= '3.10' and python_version <\= '3.11'
# agent.package_manager.pip_version.2 = >\=23,<24.3 ; python_version >\= '3.12'
# agent.package_manager.system_site_packages = false
# agent.package_manager.force_upgrade = false
# agent.package_manager.pip_legacy_resolver.0 = >\=20.3,<24.3
# agent.package_manager.conda_channels.0 = pytorch
# agent.package_manager.conda_channels.1 = conda-forge
# agent.package_manager.conda_channels.2 = nvidia
# agent.package_manager.conda_channels.3 = defaults
# agent.package_manager.priority_optional_packages.0 = pygobject
# agent.package_manager.torch_nightly = false
# agent.package_manager.poetry_files_from_repo_working_dir = false
# agent.package_manager.uv_files_from_repo_working_dir = false
# agent.venvs_dir = /root/.clearml/venvs-builds
# agent.venvs_cache.max_entries = 10
# agent.venvs_cache.free_space_threshold_gb = 2.0
# agent.venvs_cache.path = ~/.clearml/venvs-cache
# agent.vcs_cache.enabled = true
# agent.vcs_cache.path = /root/.clearml/vcs-cache
# agent.venv_update.enabled = false
# ...
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
# No tasks in queue 07cc126032d64073bc717c01760a7c7d
# No tasks in Queues, sleeping for 5.0 seconds
