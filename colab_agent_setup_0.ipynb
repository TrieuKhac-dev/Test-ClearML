# %%
import urllib.request
GITHUB_RAW_ENV_URL = 'https://raw.githubusercontent.com/TrieuKhac-dev/Test-ClearML/main/.env'
urllib.request.urlretrieve(GITHUB_RAW_ENV_URL, '.env')
print('✅ Đã tự động tải .env từ GitHub về Colab:', GITHUB_RAW_ENV_URL)

# %%
# ClearML Colab Agent Setup with pixi environment
# 1. Install pixi and setup environments
# %pip install -U pixi
# !pixi install
# !pixi run python --version  # Check pixi Python version
# %pip install clearml-agent scikit-learn numpy joblib  # Install all required packages for agent
# !clearml-agent --version  # Check agent version before running

# %%
# 2. Thiết lập credentials từ file .env
# %pip install python-dotenv
import os
from dotenv import load_dotenv
load_dotenv(dotenv_path='.env')
print(os.environ['CLEARML_API_ACCESS_KEY'])  # Kiểm tra đã load thành công

# %%
# 3. Run agent in Colab to receive tasks
print('🚦 Starting clearml-agent in Colab, Colab will act as agent for local tasks...')
# !clearml-agent --version  # Check agent version before running
# !clearml-agent daemon --queue default --foreground
